# %%
import json
with open("tickerInfo.json", 'r') as j:
    tickerInfo = json.load(j)

# %%
sector = {}
category = {}

# %% [markdown]
# put unique sector into the sector dict, otherwise print out the entry that does not have 'sector' as an attribute.

# %%
for each in tickerInfo:
    if 'sector' in each:
        if each['sector'] not in sector:
            sector[each['sector']] = 1
        else:
            sector[each['sector']] += 1
    else:
        print(each)
# Out:
# {'ticker': 'CDC'}
# {'ticker': 'CDEV'}
# {'ticker': 'CDL'}
# {'ticker': 'CDOR'}
# {'ticker': 'CELH'}
# {'ticker': 'CERC'}
# {'ticker': 'CERCW'}
# {'ticker': 'CEZ'}
# {'ticker': 'CFA'}
# {'ticker': 'CFBI'}
# {'ticker': 'CFCB'}
# {'ticker': 'CFCO'}
# {'ticker': 'CFCOU'}
# {'ticker': 'CFCOW'}
# {'ticker': 'CFO'}
# {'ticker': 'CGBD'}
# {'ticker': 'CHSCL'}
# {'ticker': 'CHSCM'}
# {'ticker': 'CHSCN'}
# {'ticker': 'CHSCO'}
# {'ticker': 'CHSCP'}
# {'ticker': 'CIBR'}
# {'ticker': 'CID'}
# {'ticker': 'CIL'}
# {'ticker': 'CISNU'}
# {'ticker': 'CISNW'}
# {'ticker': 'CIVB'}
# {'ticker': 'CIVBP'}
# {'ticker': 'CIZ'}
# {'ticker': 'CKPT'}
# {'ticker': 'CLIRW'}
# {'ticker': 'CLLS'}
# {'ticker': 'CLRBZ'}
# {'ticker': 'CNACU'}
# {'ticker': 'CNCR'}
# {'ticker': 'CODX'}
# {'ticker': 'COUP'}
# {'ticker': 'CPAA'}
# {'ticker': 'CPAAU'}
# {'ticker': 'CPAAW'}
# {'ticker': 'CPAH'}
# {'ticker': 'CPTA'}
# {'ticker': 'CPTAG'}
# {'ticker': 'CPTAL'}
# {'ticker': 'CRDT'}
# {'ticker': 'CRESY'}
# {'ticker': 'CRVS'}
# {'ticker': 'CSA'}
# {'ticker': 'CSB'}
# {'ticker': 'CSF'}
# {'ticker': 'CSML'}
# {'ticker': 'CSWI'}
# {'ticker': 'CTMX'}
# {'ticker': 'CTRE'}
# {'ticker': 'CXRX'}
# {'ticker': 'CXSE'}
# {'ticker': 'CYAD'}
# {'ticker': 'CYRXW'}
# {'ticker': 'DAX'}
# {'ticker': 'DBVT'}
# {'ticker': 'DDBI'}
# {'ticker': 'DFBG'}
# {'ticker': 'DFFN'}
# {'ticker': 'DFNL'}
# {'ticker': 'DFVL'}
# {'ticker': 'DFVS'}
# {'ticker': 'DGLT'}
# {'ticker': 'DHXM'}
# {'ticker': 'DLBL'}
# {'ticker': 'DLBS'}
# {'ticker': 'DLTH'}
# {'ticker': 'DMTX'}
# {'ticker': 'DOVA'}
# {'ticker': 'DRIOW'}
# {'ticker': 'DSGX'}
# {'ticker': 'DSKE'}
# {'ticker': 'DTRM'}
# {'ticker': 'DTUL'}
# {'ticker': 'DTUS'}
# {'ticker': 'DTYL'}
# {'ticker': 'DTYS'}
# {'ticker': 'DUSA'}
# {'ticker': 'DWAC'}
# {'ticker': 'DWAS'}
# {'ticker': 'DWAT'}
# {'ticker': 'DWFI'}
# {'ticker': 'DWIN'}
# {'ticker': 'DWLD'}
# {'ticker': 'DWLV'}
# {'ticker': 'DWTR'}
# {'ticker': 'EACQ'}
# {'ticker': 'EACQU'}
# {'ticker': 'EACQW'}
# {'ticker': 'EAGLU'}
# {'ticker': 'EAGLW'}
# {'ticker': 'EDBI'}
# {'ticker': 'EDGE'}
# {'ticker': 'EDIT'}
# {'ticker': 'EFAS'}
# {'ticker': 'EHR'}
# {'ticker': 'EIGR'}
# {'ticker': 'ELEC'}
# {'ticker': 'ELECU'}
# {'ticker': 'ELECW'}
# {'ticker': 'EMITF'}
# {'ticker': 'EPIX'}
# {'ticker': 'EQBK'}
# {'ticker': 'ERIC'}
# {'ticker': 'ESG'}
# {'ticker': 'ESGD'}
# {'ticker': 'ESGE'}
# {'ticker': 'ESGG'}
# {'ticker': 'ESGU'}
# {'ticker': 'ESLT'}
# {'ticker': 'ESQ'}
# {'ticker': 'EVGBC'}
# {'ticker': 'EVLMC'}
# {'ticker': 'EVSTC'}
# {'ticker': 'EXFO'}
# {'ticker': 'EYEGW'}
# {'ticker': 'FAAR'}
# {'ticker': 'FALN'}
# {'ticker': 'FANH'}
# {'ticker': 'FBIO'}
# {'ticker': 'FCAL'}
# {'ticker': 'FCEF'}
# {'ticker': 'FCVT'}
# {'ticker': 'FGBI'}
# {'ticker': 'FH'}
# {'ticker': 'FHB'}
# {'ticker': 'FINQ'}
# {'ticker': 'FINX'}
# {'ticker': 'FITS'}
# {'ticker': 'FIXD'}
# {'ticker': 'FKLY'}
# {'ticker': 'FKLYU'}
# {'ticker': 'FLAT'}
# {'ticker': 'FLGT'}
# {'ticker': 'FMAO'}
# {'ticker': 'FMAX'}
# {'ticker': 'FMCI'}
# {'ticker': 'FMCIR'}
# {'ticker': 'FMCIU'}
# {'ticker': 'FMCIW'}
# {'ticker': 'FNBG'}
# {'ticker': 'FNCX'}
# {'ticker': 'FNTE'}
# {'ticker': 'FNTEU'}
# {'ticker': 'FNTEW'}
# {'ticker': 'FOANC'}
# {'ticker': 'FORK'}
# {'ticker': 'FPAY'}
# {'ticker': 'FRSX'}
# {'ticker': 'FRTA'}
# {'ticker': 'FSAM'}
# {'ticker': 'FSBC'}
# {'ticker': 'FSV'}
# {'ticker': 'FTAG'}
# {'ticker': 'FTEO'}
# {'ticker': 'FTRI'}
# {'ticker': 'FTXD'}
# {'ticker': 'FTXG'}
# {'ticker': 'FTXH'}
# {'ticker': 'FTXL'}
# {'ticker': 'FTXN'}
# {'ticker': 'FTXO'}
# {'ticker': 'FTXR'}
# {'ticker': 'FUND'}
# {'ticker': 'FVC'}
# {'ticker': 'GBLIZ'}
# {'ticker': 'GDEN'}
# {'ticker': 'GECC'}
# {'ticker': 'GEMP'}
# {'ticker': 'GENE'}
# {'ticker': 'GENY'}
# {'ticker': 'GLPG'}
# {'ticker': 'GNRX'}
# {'ticker': 'GNST'}
# {'ticker': 'GNTY'}
# {'ticker': 'GNUS'}
# {'ticker': 'GOLD'}
# {'ticker': 'GOVNI'}
# {'ticker': 'GPAC'}
# {'ticker': 'GPACU'}
# {'ticker': 'GPACW'}
# {'ticker': 'GPIA'}
# {'ticker': 'GPIAU'}
# {'ticker': 'GPIAW'}
# {'ticker': 'GRFS'}
# {'ticker': 'GSHT'}
# {'ticker': 'GSHTU'}
# {'ticker': 'GSUM'}
# {'ticker': 'GTHX'}
# {'ticker': 'GTYH'}
# {'ticker': 'GTYHU'}
# {'ticker': 'GTYHW'}
# {'ticker': 'GWGH'}
# {'ticker': 'GWRS'}
# {'ticker': 'HCM'}
# {'ticker': 'HEBT'}
# {'ticker': 'HLNE'}
# {'ticker': 'HMTA'}
# {'ticker': 'HMU'}
# {'ticker': 'HONE'}
# {'ticker': 'HUNT'}
# {'ticker': 'HUNTU'}
# {'ticker': 'HVBC'}
# {'ticker': 'HYXE'}
# {'ticker': 'IAC'}
# {'ticker': 'IBUY'}
# {'ticker': 'ICCH'}
# {'ticker': 'ICHR'}
# {'ticker': 'IDLB'}
# {'ticker': 'IDXG'}
# {'ticker': 'IFMK'}
# {'ticker': 'ILG'}
# {'ticker': 'IMED'}
# {'ticker': 'IMRN'}
# {'ticker': 'IMRNW'}
# {'ticker': 'INFO'}
# {'ticker': 'INPX'}
# {'ticker': 'INSE'}
# {'ticker': 'INSG'}
# {'ticker': 'INVA'}
# {'ticker': 'IONS'}
# {'ticker': 'IOTS'}
# {'ticker': 'IRCP'}
# {'ticker': 'IRTC'}
# {'ticker': 'AABA'}
# {'ticker': 'ABDC'}
# {'ticker': 'ABEO'}
# {'ticker': 'ABEOW'}
# {'ticker': 'ABIL'}
# {'ticker': 'ABTX'}
# {'ticker': 'ACBI'}
# {'ticker': 'ACCP'}
# {'ticker': 'ACCPW'}
# {'ticker': 'ACGLP'}
# {'ticker': 'ACRS'}
# {'ticker': 'ADOM'}
# {'ticker': 'ADVM'}
# {'ticker': 'AFHBL'}
# {'ticker': 'AGFSW'}
# {'ticker': 'AGLE'}
# {'ticker': 'AHPA'}
# {'ticker': 'AHPAU'}
# {'ticker': 'AHPAW'}
# {'ticker': 'AIRG'}
# {'ticker': 'AKCA'}
# {'ticker': 'AKER'}
# {'ticker': 'AKTS'}
# {'ticker': 'AKTX'}
# {'ticker': 'ALJJ'}
# {'ticker': 'ALRN'}
# {'ticker': 'ALTY'}
# {'ticker': 'AMMA'}
# {'ticker': 'ANAB'}
# {'ticker': 'ANDA'}
# {'ticker': 'ANDAR'}
# {'ticker': 'APDNW'}
# {'ticker': 'APLP'}
# {'ticker': 'APOP'}
# {'ticker': 'APOPW'}
# {'ticker': 'APPN'}
# {'ticker': 'APPS'}
# {'ticker': 'APTI'}
# {'ticker': 'APTO'}
# {'ticker': 'APVO'}
# {'ticker': 'AQB'}
# {'ticker': 'ARGS'}
# {'ticker': 'ARGX'}
# {'ticker': 'ARLZ'}
# {'ticker': 'ASET'}
# {'ticker': 'ASML'}
# {'ticker': 'ASV'}
# {'ticker': 'ATNX'}
# {'ticker': 'ATOM'}
# {'ticker': 'ATRA'}
# {'ticker': 'ATXI'}
# {'ticker': 'AUPH'}
# {'ticker': 'AVIR'}
# {'ticker': 'AVXS'}
# {'ticker': 'AXAR'}
# {'ticker': 'AXARU'}
# {'ticker': 'AXARW'}
# {'ticker': 'AXSM'}
# {'ticker': 'AYA'}
# {'ticker': 'AZRX'}
# {'ticker': 'BANFP'}
# {'ticker': 'BANX'}
# {'ticker': 'BATRK'}
# {'ticker': 'BBC'}
# {'ticker': 'BBP'}
# {'ticker': 'BBRX'}
# {'ticker': 'BBRY'}
# {'ticker': 'BCACU'}
# {'ticker': 'BCTF'}
# {'ticker': 'BFIT'}
# {'ticker': 'BGNE'}
# {'ticker': 'BIVV'}
# {'ticker': 'BL'}
# {'ticker': 'BLRX'}
# {'ticker': 'BMCH'}
# {'ticker': 'BMLA'}
# {'ticker': 'BMRA'}
# {'ticker': 'BNTCW'}
# {'ticker': 'BOMN'}
# {'ticker': 'BOTZ'}
# {'ticker': 'BOXL'}
# {'ticker': 'BSTG'}
# {'ticker': 'BTEC'}
# {'ticker': 'BUR'}
# {'ticker': 'BVXV'}
# {'ticker': 'BVXVW'}
# {'ticker': 'BYSI'}
# {'ticker': 'CACG'}
# {'ticker': 'CASC'}
# {'ticker': 'CATH'}
# {'ticker': 'CATS'}
# {'ticker': 'CBIO'}
# {'ticker': 'CBMG'}
# {'ticker': 'CCD'}
# {'ticker': 'CCFI'}
# {'ticker': 'CCRC'}
# {'ticker': 'ITEQ'}
# {'ticker': 'ITRN'}
# {'ticker': 'IVENC'}
# {'ticker': 'IVFGC'}
# {'ticker': 'IVFVC'}
# {'ticker': 'JMU'}
# {'ticker': 'JNCE'}
# {'ticker': 'JSMD'}
# {'ticker': 'JSML'}
# {'ticker': 'JSYN'}
# {'ticker': 'JSYNR'}
# {'ticker': 'JSYNU'}
# {'ticker': 'JSYNW'}
# {'ticker': 'JTPY'}
# {'ticker': 'KAAC'}
# {'ticker': 'KAACU'}
# {'ticker': 'KAACW'}
# {'ticker': 'KBLM'}
# {'ticker': 'KBLMR'}
# {'ticker': 'KBLMU'}
# {'ticker': 'KBLMW'}
# {'ticker': 'KBWD'}
# {'ticker': 'KBWY'}
# {'ticker': 'KMDA'}
# {'ticker': 'KNSL'}
# {'ticker': 'KRMA'}
# {'ticker': 'KTOV'}
# {'ticker': 'KTOVW'}
# {'ticker': 'KURA'}
# {'ticker': 'LAUR'}
# {'ticker': 'LCA'}
# {'ticker': 'LCAHU'}
# {'ticker': 'LCAHW'}
# {'ticker': 'LEXEA'}
# {'ticker': 'LEXEB'}
# {'ticker': 'LINK'}
# {'ticker': 'LITE'}
# {'ticker': 'LIVN'}
# {'ticker': 'LKOR'}
# {'ticker': 'LLIT'}
# {'ticker': 'LMFA'}
# {'ticker': 'LMFAW'}
# {'ticker': 'LMRKO'}
# {'ticker': 'LMRKP'}
# {'ticker': 'LNGR'}
# {'ticker': 'LNTH'}
# {'ticker': 'LOGI'}
# {'ticker': 'LONE'}
# {'ticker': 'LPTX'}
# {'ticker': 'LRGE'}
# {'ticker': 'LSXMA'}
# {'ticker': 'LSXMB'}
# {'ticker': 'LSXMK'}
# {'ticker': 'LTEA'}
# {'ticker': 'LTXB'}
# {'ticker': 'LVHD'}
# {'ticker': 'MACQ'}
# {'ticker': 'MACQU'}
# {'ticker': 'MACQW'}
# {'ticker': 'MAUI'}
# {'ticker': 'MBCN'}
# {'ticker': 'MBRX'}
# {'ticker': 'MBVX'}
# {'ticker': 'MCEF'}
# {'ticker': 'MDGL'}
# {'ticker': 'MDGS'}
# {'ticker': 'MEDP'}
# {'ticker': 'MESO'}
# {'ticker': 'METC'}
# {'ticker': 'MGEN'}
# {'ticker': 'MIII'}
# {'ticker': 'MIIIU'}
# {'ticker': 'MIIIW'}
# {'ticker': 'MILN'}
# {'ticker': 'MIME'}
# {'ticker': 'MIRN'}
# {'ticker': 'MMAC'}
# {'ticker': 'MMDM'}
# {'ticker': 'MMDMR'}
# {'ticker': 'MMDMU'}
# {'ticker': 'MMDMW'}
# {'ticker': 'MOGLC'}
# {'ticker': 'MOTA'}
# {'ticker': 'MOTAW'}
# {'ticker': 'MOXC'}
# {'ticker': 'MPAC'}
# {'ticker': 'MPACU'}
# {'ticker': 'MPACW'}
# {'ticker': 'MPCT'}
# {'ticker': 'MRAM'}
# {'ticker': 'MRDN'}
# {'ticker': 'MRDNW'}
# {'ticker': 'MRSN'}
# {'ticker': 'MRUS'}
# {'ticker': 'MSBI'}
# {'ticker': 'MSDIW'}
# {'ticker': 'MSLI'}
# {'ticker': 'MTBCP'}
# {'ticker': 'MTCH'}
# {'ticker': 'MTFB'}
# {'ticker': 'MTFBW'}
# {'ticker': 'MTP'}
# {'ticker': 'MYND'}
# {'ticker': 'MYNDW'}
# {'ticker': 'MYO'}
# {'ticker': 'MYOK'}
# {'ticker': 'MYSZ'}
# {'ticker': 'MZOR'}
# {'ticker': 'NAKD'}
# {'ticker': 'NBEV'}
# {'ticker': 'NBRV'}
# {'ticker': 'NCSM'}
# {'ticker': 'NDRA'}
# {'ticker': 'NDRAU'}
# {'ticker': 'NDRAW'}
# {'ticker': 'NEPT'}
# {'ticker': 'NESR'}
# {'ticker': 'NESRU'}
# {'ticker': 'NESRW'}
# {'ticker': 'NH'}
# {'ticker': 'NHLDW'}
# {'ticker': 'NICE'}
# {'ticker': 'NODK'}
# {'ticker': 'NOVN'}
# {'ticker': 'NOVT'}
# {'ticker': 'NTEC'}
# {'ticker': 'NTLA'}
# {'ticker': 'NTRP'}
# {'ticker': 'NVCN'}
# {'ticker': 'NVCR'}
# {'ticker': 'NVTR'}
# {'ticker': 'NXEOW'}
# {'ticker': 'OACQW'}
# {'ticker': 'OASM'}
# {'ticker': 'OBLN'}
# {'ticker': 'OBSV'}
# {'ticker': 'OHAI'}
# {'ticker': 'OKTA'}
# {'ticker': 'OLD'}
# {'ticker': 'OMAB'}
# {'ticker': 'OMNT'}
# {'ticker': 'ONS'}
# {'ticker': 'ONSIW'}
# {'ticker': 'ONSIZ'}
# {'ticker': 'ONTXW'}
# {'ticker': 'ORG'}
# {'ticker': 'OTG'}
# {'ticker': 'OVID'}
# {'ticker': 'OXBR'}
# {'ticker': 'OXBRW'}
# {'ticker': 'OXLC'}
# {'ticker': 'OXLCM'}
# {'ticker': 'OXLCN'}
# {'ticker': 'OXLCO'}
# {'ticker': 'PAAC'}
# {'ticker': 'PAACR'}
# {'ticker': 'PAACU'}
# {'ticker': 'PAACW'}
# {'ticker': 'PAAS'}
# {'ticker': 'PAVM'}
# {'ticker': 'PAVMW'}
# {'ticker': 'PBBI'}
# {'ticker': 'PBNC'}
# {'ticker': 'PCOM'}
# {'ticker': 'PCSB'}
# {'ticker': 'PFI'}
# {'ticker': 'PHO'}
# {'ticker': 'PID'}
# {'ticker': 'PIXY'}
# {'ticker': 'PLAY'}
# {'ticker': 'PLSE'}
# {'ticker': 'PLYA'}
# {'ticker': 'PLYAW'}
# {'ticker': 'PMPT'}
# {'ticker': 'PMTS'}
# {'ticker': 'POLA'}
# {'ticker': 'PPSI'}
# {'ticker': 'PRAN'}
# {'ticker': 'PSA_S-CL'}
# {'ticker': 'PSC'}
# {'ticker': 'PSDO'}
# {'ticker': 'PSET'}
# {'ticker': 'PSL'}
# {'ticker': 'PTF'}
# {'ticker': 'PTH'}
# {'ticker': 'PUI'}
# {'ticker': 'PVAC'}
# {'ticker': 'PXI'}
# {'ticker': 'PXS'}
# {'ticker': 'PY'}
# {'ticker': 'PYZ'}
# {'ticker': 'PZRX'}
# {'ticker': 'QLC'}
# {'ticker': 'QRHC'}
# {'ticker': 'QTNT'}
# {'ticker': 'QTRH'}
# {'ticker': 'RBIO'}
# {'ticker': 'RCM'}
# {'ticker': 'RDHL'}
# {'ticker': 'RDUS'}
# {'ticker': 'RETA'}
# {'ticker': 'RFAP'}
# {'ticker': 'RFDI'}
# {'ticker': 'RFEM'}
# {'ticker': 'RFEU'}
# {'ticker': 'RGNX'}
# {'ticker': 'RILYZ'}
# {'ticker': 'RMR'}
# {'ticker': 'RNDB'}
# {'ticker': 'RNDM'}
# {'ticker': 'RNDV'}
# {'ticker': 'RNEM'}
# {'ticker': 'RNLC'}
# {'ticker': 'RNMC'}
# {'ticker': 'RNSC'}
# {'ticker': 'RNVA'}
# {'ticker': 'RNVAZ'}
# {'ticker': 'ROSE'}
# {'ticker': 'ROSEU'}
# {'ticker': 'ROSEW'}
# {'ticker': 'RSAS'}
# {'ticker': 'RTNB'}
# {'ticker': 'RYAAY'}
# {'ticker': 'SAMG'}
# {'ticker': 'SAUC'}
# {'ticker': 'SBBP'}
# {'ticker': 'SBOT'}
# {'ticker': 'SBPH'}
# {'ticker': 'SCAC'}
# {'ticker': 'SCACU'}
# {'ticker': 'SCACW'}
# {'ticker': 'SCWX'}
# {'ticker': 'SELB'}
# {'ticker': 'SELF'}
# {'ticker': 'SGBX'}
# {'ticker': 'SGH'}
# {'ticker': 'SGLB'}
# {'ticker': 'SGLBW'}
# {'ticker': 'SGRY'}
# {'ticker': 'SGY-WS'}
# {'ticker': 'SHIPW'}
# {'ticker': 'SHPG'}
# {'ticker': 'SHSP'}
# {'ticker': 'SIEN'}
# {'ticker': 'SIVBO'}
# {'ticker': 'SLIM'}
# {'ticker': 'SLNO'}
# {'ticker': 'SLNOW'}
# {'ticker': 'SMBK'}
# {'ticker': 'SMCP'}
# {'ticker': 'SMMT'}
# {'ticker': 'SNDE'}
# {'ticker': 'SNDX'}
# {'ticker': 'SNES'}
# {'ticker': 'SNGX'}
# {'ticker': 'SNGXW'}
# {'ticker': 'SNSR'}
# {'ticker': 'SOHOM'}
# {'ticker': 'SPI'}
# {'ticker': 'SPIL'}
# {'ticker': 'SPKEP'}
# {'ticker': 'SQZZ'}
# {'ticker': 'SRAX'}
# {'ticker': 'SRSC'}
# {'ticker': 'SRTS'}
# {'ticker': 'SRTSW'}
# {'ticker': 'SRUN'}
# {'ticker': 'SRUNU'}
# {'ticker': 'SRUNW'}
# {'ticker': 'SSKN'}
# {'ticker': 'SSNT'}
# {'ticker': 'SSTI'}
# {'ticker': 'STKL'}
# {'ticker': 'STLR'}
# {'ticker': 'STLRU'}
# {'ticker': 'STLRW'}
# {'ticker': 'STPP'}
# {'ticker': 'SUNW'}
# {'ticker': 'SWIN'}
# {'ticker': 'SWIR'}
# {'ticker': 'TAPR'}
# {'ticker': 'TGEN'}
# {'ticker': 'TICCL'}
# {'ticker': 'TIG'}
# {'ticker': 'TIL'}
# {'ticker': 'TLGT'}
# {'ticker': 'TNTR'}
# {'ticker': 'TOCA'}
# {'ticker': 'TPIV'}
# {'ticker': 'TRCH'}
# {'ticker': 'TRHC'}
# {'ticker': 'TRIL'}
# {'ticker': 'TRPX'}
# {'ticker': 'TRVG'}
# {'ticker': 'TUSK'}
# {'ticker': 'TUTI'}
# {'ticker': 'TUTT'}
# {'ticker': 'TVIA'}
# {'ticker': 'TWNK'}
# {'ticker': 'TWNKW'}
# {'ticker': 'UBIO'}
# {'ticker': 'UBND'}
# {'ticker': 'UDBI'}
# {'ticker': 'ULH'}
# {'ticker': 'UPL'}
# {'ticker': 'URGN'}
# {'ticker': 'USLB'}
# {'ticker': 'USOI'}
# {'ticker': 'VALX'}
# {'ticker': 'VBLT'}
# {'ticker': 'VBND'}
# {'ticker': 'VEAC'}
# {'ticker': 'VEACU'}
# {'ticker': 'VEACW'}
# {'ticker': 'VERI'}
# {'ticker': 'VIAV'}
# {'ticker': 'VIGI'}
# {'ticker': 'VKTXW'}
# {'ticker': 'VLRX'}
# {'ticker': 'VMET'}
# {'ticker': 'VOD'}
# {'ticker': 'VREX'}
# {'ticker': 'VRIG'}
# {'ticker': 'VRNA'}
# {'ticker': 'VSMV'}
# {'ticker': 'VTVT'}
# {'ticker': 'VVPR'}
# {'ticker': 'VWR'}
# {'ticker': 'VYGR'}
# {'ticker': 'VYMI'}
# {'ticker': 'WCFB'}
# {'ticker': 'WEB'}
# {'ticker': 'WHLRD'}
# {'ticker': 'WINS'}
# {'ticker': 'WKHS'}
# {'ticker': 'WLTW'}
# {'ticker': 'WMGIZ'}
# {'ticker': 'WMIH'}
# {'ticker': 'WNFM'}
# {'ticker': 'WPPGY'}
# {'ticker': 'WVE'}
# {'ticker': 'WYIG'}
# {'ticker': 'WYIGU'}
# {'ticker': 'WYIGW'}
# {'ticker': 'XBIO'}
# {'ticker': 'XOG'}
# {'ticker': 'XPER'}
# {'ticker': 'XRDC'}
# {'ticker': 'XTLB'}
# {'ticker': 'YERR'}
# {'ticker': 'YGYI'}
# {'ticker': 'YIN'}
# {'ticker': 'YLDE'}
# {'ticker': 'YTEN'}
# {'ticker': 'YTRA'}
# {'ticker': 'ZBIO'}
# {'ticker': 'ZJZZT'}
# {'ticker': 'ABEV'}
# {'ticker': 'ABR_A'}
# {'ticker': 'ABR_B'}
# {'ticker': 'ABR_C'}
# {'ticker': 'AC'}
# {'ticker': 'ACP'}
# {'ticker': 'ACSI'}
# {'ticker': 'AEB'}
# {'ticker': 'AED'}
# {'ticker': 'AEG'}
# {'ticker': 'AEH'}
# {'ticker': 'AEK'}
# {'ticker': 'AES_C-CL'}
# {'ticker': 'AF_C'}
# {'ticker': 'AFC'}
# {'ticker': 'AFI'}
# {'ticker': 'AFSI_A'}
# {'ticker': 'AFSI_B'}
# {'ticker': 'AFSI_C'}
# {'ticker': 'AFSI_D'}
# {'ticker': 'AFSI_E'}
# {'ticker': 'AFSI_F'}
# {'ticker': 'AFT'}
# {'ticker': 'AFTY'}
# {'ticker': 'AFW-CL'}
# {'ticker': 'AGC'}
# {'ticker': 'AGGE'}
# {'ticker': 'AGGP'}
# {'ticker': 'AGGY'}
# {'ticker': 'AGM_A'}
# {'ticker': 'AGM_B'}
# {'ticker': 'AGM_C'}
# {'ticker': 'AGN_A'}
# {'ticker': 'AGO_B'}
# {'ticker': 'AGO_E'}
# {'ticker': 'AGO_F'}
# {'ticker': 'AGR'}
# {'ticker': 'AGT'}
# {'ticker': 'AHL_B-CL'}
# {'ticker': 'AHL_C'}
# {'ticker': 'AHL_D'}
# {'ticker': 'AHP_B'}
# {'ticker': 'AHT_A'}
# {'ticker': 'AHT_D'}
# {'ticker': 'AHT_F'}
# {'ticker': 'AHT_G'}
# {'ticker': 'AI_B'}
# {'ticker': 'AIF'}
# {'ticker': 'AIG-WS'}
# {'ticker': 'AIV_A'}
# {'ticker': 'AJXA'}
# {'ticker': 'AKO-A'}
# {'ticker': 'AKO-B'}
# {'ticker': 'ALFI'}
# {'ticker': 'ALL_A'}
# {'ticker': 'ALL_B'}
# {'ticker': 'ALL_C'}
# {'ticker': 'ALL_D'}
# {'ticker': 'ALL_E'}
# {'ticker': 'ALL_F'}
# {'ticker': 'ALLY_A'}
# {'ticker': 'ALP_O'}
# {'ticker': 'ALR_B'}
# {'ticker': 'AMFW'}
# {'ticker': 'AMGP'}
# {'ticker': 'AMH_A'}
# {'ticker': 'AMH_B'}
# {'ticker': 'AMH_C'}
# {'ticker': 'AMH_D'}
# {'ticker': 'AMH_E'}
# {'ticker': 'AMH_F'}
# {'ticker': 'AMJL'}
# {'ticker': 'AMLX'}
# {'ticker': 'AMT_B'}
# {'ticker': 'AMZA'}
# {'ticker': 'ANH_A'}
# {'ticker': 'ANH_B'}
# {'ticker': 'ANH_C'}
# {'ticker': 'APLE'}
# {'ticker': 'APO_A'}
# {'ticker': 'APRN'}
# {'ticker': 'AQN'}
# {'ticker': 'ARA'}
# {'ticker': 'ARCH'}
# {'ticker': 'ARCM'}
# {'ticker': 'ARD'}
# {'ticker': 'ARDC'}
# {'ticker': 'ARE_D'}
# {'ticker': 'ARES_A'}
# {'ticker': 'ARH_C'}
# {'ticker': 'ARI_A'}
# {'ticker': 'ARI_C'}
# {'ticker': 'ARKG'}
# {'ticker': 'ARKK'}
# {'ticker': 'ARKQ'}
# {'ticker': 'ARKW'}
# {'ticker': 'ARNC_B'}
# {'ticker': 'AROC'}
# {'ticker': 'ARR_A'}
# {'ticker': 'ARR_B'}
# {'ticker': 'ARU-CL'}
# {'ticker': 'ASB_C'}
# {'ticker': 'ASB_D'}
# {'ticker': 'ASHX'}
# {'ticker': 'ATGE'}
# {'ticker': 'ATH'}
# {'ticker': 'ATUS'}
# {'ticker': 'AVAL'}
# {'ticker': 'AVH'}
# {'ticker': 'AVK'}
# {'ticker': 'AXS_D'}
# {'ticker': 'AXS_E'}
# {'ticker': 'AYX'}
# {'ticker': 'AZRE'}
# {'ticker': 'AZUL'}
# {'ticker': 'BAC-WS-A'}
# {'ticker': 'BAC-WS-B'}
# {'ticker': 'BAC_A'}
# {'ticker': 'BAC_C'}
# {'ticker': 'BAC_D'}
# {'ticker': 'BAC_E'}
# {'ticker': 'BAC_I'}
# {'ticker': 'BAC_L'}
# {'ticker': 'BAC_W'}
# {'ticker': 'BAC_Y'}
# {'ticker': 'BANC_C'}
# {'ticker': 'BANC_D'}
# {'ticker': 'BANC_E'}
# {'ticker': 'BBT_D'}
# {'ticker': 'BBT_E'}
# {'ticker': 'BBT_F'}
# {'ticker': 'BBT_G'}
# {'ticker': 'BBT_H'}
# {'ticker': 'BBU'}
# {'ticker': 'BCD'}
# {'ticker': 'BCI'}
# {'ticker': 'BCS_D'}
# {'ticker': 'BDC_B'}
# {'ticker': 'BDCZ'}
# {'ticker': 'BDXA'}
# {'ticker': 'BEDU'}
# {'ticker': 'BEF'}
# {'ticker': 'BEMO'}
# {'ticker': 'BF-A'}
# {'ticker': 'BF-B'}
# {'ticker': 'BFS_C'}
# {'ticker': 'BGE_B'}
# {'ticker': 'BGIO'}
# {'ticker': 'BGX'}
# {'ticker': 'BHL'}
# {'ticker': 'BHVN'}
# {'ticker': 'BIGD'}
# {'ticker': 'BIO-B'}
# {'ticker': 'BIT'}
# {'ticker': 'BK_C'}
# {'ticker': 'BLES'}
# {'ticker': 'BLHY'}
# {'ticker': 'BLW'}
# {'ticker': 'BML_G'}
# {'ticker': 'BML_H'}
# {'ticker': 'BML_I'}
# {'ticker': 'BML_J'}
# {'ticker': 'BML_L'}
# {'ticker': 'BMLP'}
# {'ticker': 'BNDC'}
# {'ticker': 'BNDS'}
# {'ticker': 'BOSS'}
# {'ticker': 'BRK-A'}
# {'ticker': 'BRK-B'}
# {'ticker': 'BSCP'}
# {'ticker': 'BSCQ'}
# {'ticker': 'BSJN'}
# {'ticker': 'BSJO'}
# {'ticker': 'BSL'}
# {'ticker': 'BST'}
# {'ticker': 'BSWN'}
# {'ticker': 'BTU'}
# {'ticker': 'BUZ'}
# {'ticker': 'BVAL'}
# {'ticker': 'BWG'}
# {'ticker': 'BXP_B'}
# {'ticker': 'BY'}
# {'ticker': 'C-WS-A'}
# {'ticker': 'C_C'}
# {'ticker': 'C_J'}
# {'ticker': 'C_K'}
# {'ticker': 'C_L'}
# {'ticker': 'C_N'}
# {'ticker': 'C_P'}
# {'ticker': 'C_S'}
# {'ticker': 'CAA'}
# {'ticker': 'CADE'}
# {'ticker': 'CAI'}
# {'ticker': 'CALF'}
# {'ticker': 'CARS'}
# {'ticker': 'CBA'}
# {'ticker': 'CBB_B'}
# {'ticker': 'CBH'}
# {'ticker': 'CBL_D'}
# {'ticker': 'CBL_E'}
# {'ticker': 'CBO'}
# {'ticker': 'CBS-A'}
# {'ticker': 'CBX'}
# {'ticker': 'CCOR'}
# {'ticker': 'CDR_B'}
# {'ticker': 'CEE'}
# {'ticker': 'CEFS'}
# {'ticker': 'CEM'}
# {'ticker': 'CEMB'}
# {'ticker': 'CEN'}
# {'ticker': 'CETXP'}
# {'ticker': 'CETXW'}
# {'ticker': 'CFC_B'}
# {'ticker': 'CFG'}
# {'ticker': 'CFR_A'}
# {'ticker': 'CHAD'}
# {'ticker': 'CHCT'}
# {'ticker': 'CHK_D'}
# {'ticker': 'CHSP_A-CL'}
# {'ticker': 'CIG-C'}
# {'ticker': 'CIG'}
# {'ticker': 'CIM_A'}
# {'ticker': 'CIM_B'}
# {'ticker': 'CINR'}
# {'ticker': 'CIO_A'}
# {'ticker': 'CISN'}
# {'ticker': 'CJ'}
# {'ticker': 'CLA-CL'}
# {'ticker': 'CLA_'}
# {'ticker': 'CLAW'}
# {'ticker': 'CLDR'}
# {'ticker': 'CLNS'}
# {'ticker': 'CLNS_A-CL'}
# {'ticker': 'CLNS_B'}
# {'ticker': 'CLNS_C'}
# {'ticker': 'CLNS_D'}
# {'ticker': 'CLNS_E'}
# {'ticker': 'CLNS_F-CL'}
# {'ticker': 'CLNS_G'}
# {'ticker': 'CLNS_H'}
# {'ticker': 'CLNS_I'}
# {'ticker': 'CLPR'}
# {'ticker': 'CLTL'}
# {'ticker': 'CLYH'}
# {'ticker': 'CMA-WS'}
# {'ticker': 'CMD'}
# {'ticker': 'CMO_E'}
# {'ticker': 'CMRE_B'}
# {'ticker': 'CMRE_C'}
# {'ticker': 'CMRE_D'}
# {'ticker': 'CMS_B'}
# {'ticker': 'CNDF'}
# {'ticker': 'CNDT'}
# {'ticker': 'CNHX'}
# {'ticker': 'CNSF'}
# {'ticker': 'CNXC'}
# {'ticker': 'CNYA'}
# {'ticker': 'CODI_A'}
# {'ticker': 'COE'}
# {'ticker': 'COF-WS'}
# {'ticker': 'COF_C'}
# {'ticker': 'COF_D'}
# {'ticker': 'COF_F'}
# {'ticker': 'COF_G'}
# {'ticker': 'COF_H'}
# {'ticker': 'COF_P'}
# {'ticker': 'COM'}
# {'ticker': 'COMB'}
# {'ticker': 'COMG'}
# {'ticker': 'COR_A'}
# {'ticker': 'CORR_A'}
# {'ticker': 'COWZ'}
# {'ticker': 'CPE_A'}
# {'ticker': 'CRAK'}
# {'ticker': 'CRD-A'}
# {'ticker': 'CRD-B'}
# {'ticker': 'CSRA'}
# {'ticker': 'CTAA'}
# {'ticker': 'CTBB'}
# {'ticker': 'CTDD'}
# {'ticker': 'CTR'}
# {'ticker': 'CTU'}
# {'ticker': 'CTV'}
# {'ticker': 'CTW'}
# {'ticker': 'CTX'}
# {'ticker': 'CTY'}
# {'ticker': 'CTZ'}
# {'ticker': 'CUBI_C'}
# {'ticker': 'CUBI_D'}
# {'ticker': 'CUBI_E'}
# {'ticker': 'CUBI_F'}
# {'ticker': 'CUMB'}
# {'ticker': 'CVNA'}
# {'ticker': 'CWAI'}
# {'ticker': 'CWEB'}
# {'ticker': 'CWS'}
# {'ticker': 'CYS_A'}
# {'ticker': 'CYS_B'}
# {'ticker': 'DBES'}
# {'ticker': 'DBIT'}
# {'ticker': 'DCP'}
# {'ticker': 'DD_A'}
# {'ticker': 'DD_B'}
# {'ticker': 'DDEZ'}
# {'ticker': 'DDJP'}
# {'ticker': 'DDLS'}
# {'ticker': 'DDR_A'}
# {'ticker': 'DDR_J'}
# {'ticker': 'DDR_K'}
# {'ticker': 'DDWM'}
# {'ticker': 'DEA'}
# {'ticker': 'DEEF'}
# {'ticker': 'DEFA'}
# {'ticker': 'DEMG'}
# {'ticker': 'DESC'}
# {'ticker': 'DEUS'}
# {'ticker': 'DEWJ'}
# {'ticker': 'DEZU'}
# {'ticker': 'DFEN'}
# {'ticker': 'DFIN'}
# {'ticker': 'DFND'}
# {'ticker': 'DFP'}
# {'ticker': 'DFS_B'}
# {'ticker': 'DFT_C'}
# {'ticker': 'DHDG'}
# {'ticker': 'DHG'}
# {'ticker': 'DHVW'}
# {'ticker': 'DIAX'}
# {'ticker': 'DIVA'}
# {'ticker': 'DIVC'}
# {'ticker': 'DIVO'}
# {'ticker': 'DIVY'}
# {'ticker': 'DJD'}
# {'ticker': 'DKT'}
# {'ticker': 'DLNG_A'}
# {'ticker': 'DLR_G'}
# {'ticker': 'DLR_H'}
# {'ticker': 'DLR_I'}
# {'ticker': 'DMB'}
# {'ticker': 'DMO'}
# {'ticker': 'DPST'}
# {'ticker': 'DS_B'}
# {'ticker': 'DS_C'}
# {'ticker': 'DS_D'}
# {'ticker': 'DSE'}
# {'ticker': 'DSX_B'}
# {'ticker': 'DTK'}
# {'ticker': 'DTLA_'}
# {'ticker': 'DTV'}
# {'ticker': 'DULL'}
# {'ticker': 'DUSL'}
# {'ticker': 'DVEM'}
# {'ticker': 'DVP'}
# {'ticker': 'DWT'}
# {'ticker': 'DX_A'}
# {'ticker': 'DX_B'}
# {'ticker': 'DXB'}
# {'ticker': 'DXC'}
# {'ticker': 'DXUS'}
# {'ticker': 'DYB'}
# {'ticker': 'DYLS'}
# {'ticker': 'DYN-WS-A'}
# {'ticker': 'DYN-WS'}
# {'ticker': 'DYN_A'}
# {'ticker': 'EAB'}
# {'ticker': 'EAE'}
# {'ticker': 'EAI'}
# {'ticker': 'EBR-B'}
# {'ticker': 'ECC'}
# {'ticker': 'ECCA'}
# {'ticker': 'ECCB'}
# {'ticker': 'ECCZ'}
# {'ticker': 'EDF'}
# {'ticker': 'EDOM'}
# {'ticker': 'EEA'}
# {'ticker': 'EEMO'}
# {'ticker': 'EEMX'}
# {'ticker': 'EEX'}
# {'ticker': 'EFAX'}
# {'ticker': 'EFF'}
# {'ticker': 'EFNL'}
# {'ticker': 'EGIF'}
# {'ticker': 'EHT'}
# {'ticker': 'ELC'}
# {'ticker': 'ELJ'}
# {'ticker': 'ELS_C'}
# {'ticker': 'ELU'}
# {'ticker': 'ELVT'}
# {'ticker': 'EMBH'}
# {'ticker': 'EMDD'}
# {'ticker': 'EMDV'}
# {'ticker': 'EMGF'}
# {'ticker': 'EMHY'}
# {'ticker': 'EMO'}
# {'ticker': 'EMP'}
# {'ticker': 'EMQQ'}
# {'ticker': 'EMSD'}
# {'ticker': 'EMTL'}
# {'ticker': 'ENH_C'}
# {'ticker': 'ENIA'}
# {'ticker': 'ENIC'}
# {'ticker': 'ENJ'}
# {'ticker': 'ENO'}
# {'ticker': 'ENOR'}
# {'ticker': 'EOCC'}
# {'ticker': 'EOT'}
# {'ticker': 'EP_C'}
# {'ticker': 'EPR_C'}
# {'ticker': 'EPR_E'}
# {'ticker': 'EPR_F'}
# {'ticker': 'EPRF'}
# {'ticker': 'EQC'}
# {'ticker': 'EQC_D'}
# {'ticker': 'EQCO'}
# {'ticker': 'ERGF'}
# {'ticker': 'ERM'}
# {'ticker': 'ESGF'}
# {'ticker': 'ESGL'}
# {'ticker': 'ESGN'}
# {'ticker': 'ESGS'}
# {'ticker': 'ESGW'}
# {'ticker': 'ETHO'}
# {'ticker': 'ETJ'}
# {'ticker': 'ETX'}
# {'ticker': 'EUDV'}
# {'ticker': 'EUFL'}
# {'ticker': 'EUFS'}
# {'ticker': 'EURN'}
# {'ticker': 'EVER_A'}
# {'ticker': 'EVHC_'}
# {'ticker': 'EVIX'}
# {'ticker': 'EVRI'}
# {'ticker': 'EWGS'}
# {'ticker': 'EWMC'}
# {'ticker': 'EWRE'}
# {'ticker': 'EWSC'}
# {'ticker': 'EWUS'}
# {'ticker': 'EXIV'}
# {'ticker': 'EXTN'}
# {'ticker': 'EYESW'}
# {'ticker': 'EYLD'}
# {'ticker': 'EZT'}
# {'ticker': 'FBK'}
# {'ticker': 'FBM'}
# {'ticker': 'FCAU'}
# {'ticker': 'FCE-A'}
# {'ticker': 'FCE-B'}
# {'ticker': 'FCH_A'}
# {'ticker': 'FCPT'}
# {'ticker': 'FDC'}
# {'ticker': 'FDEU'}
# {'ticker': 'FDLO'}
# {'ticker': 'FDMO'}
# {'ticker': 'FDRR'}
# {'ticker': 'FDVV'}
# {'ticker': 'FFC'}
# {'ticker': 'FFHG'}
# {'ticker': 'FFTI'}
# {'ticker': 'FFTY'}
# {'ticker': 'FHN_A'}
# {'ticker': 'FIBR'}
# {'ticker': 'FIEE'}
# {'ticker': 'FIHD'}
# {'ticker': 'FISK'}
# {'ticker': 'FIV'}
# {'ticker': 'FLCO'}
# {'ticker': 'FLEU'}
# {'ticker': 'FLIO'}
# {'ticker': 'FLLV'}
# {'ticker': 'FLQD'}
# {'ticker': 'FLQE'}
# {'ticker': 'FLQG'}
# {'ticker': 'FLQH'}
# {'ticker': 'FLQL'}
# {'ticker': 'FLQM'}
# {'ticker': 'FLQS'}
# {'ticker': 'FNB_E'}
# {'ticker': 'FNCF'}
# {'ticker': 'FND'}
# {'ticker': 'FPH'}
# {'ticker': 'FQAL'}
# {'ticker': 'FRAC'}
# {'ticker': 'FRC_B-CL'}
# {'ticker': 'FRC_C'}
# {'ticker': 'FRC_D'}
# {'ticker': 'FRC_E'}
# {'ticker': 'FRC_F'}
# {'ticker': 'FRC_G'}
# {'ticker': 'FRC_H'}
# {'ticker': 'FUT'}
# {'ticker': 'FVAL'}
# {'ticker': 'FXEP'}
# {'ticker': 'FXJP'}
# {'ticker': 'GAB_D'}
# {'ticker': 'GAB_G'}
# {'ticker': 'GAB_H'}
# {'ticker': 'GAB_J'}
# {'ticker': 'GAM_B'}
# {'ticker': 'GAMR'}
# {'ticker': 'GARD'}
# {'ticker': 'GASX'}
# {'ticker': 'GATX'}
# {'ticker': 'GAZB'}
# {'ticker': 'GBAB'}
# {'ticker': 'GBIL'}
# {'ticker': 'GBLIL'}
# {'ticker': 'GCOW'}
# {'ticker': 'GCP'}
# {'ticker': 'GCV_B'}
# {'ticker': 'GDI'}
# {'ticker': 'GDL_B'}
# {'ticker': 'GDO'}
# {'ticker': 'GDV_A'}
# {'ticker': 'GDV_D'}
# {'ticker': 'GDV_G'}
# {'ticker': 'GDVD'}
# {'ticker': 'GEB'}
# {'ticker': 'GEF-B'}
# {'ticker': 'GEH'}
# {'ticker': 'GEK'}
# {'ticker': 'GEM'}
# {'ticker': 'GF'}
# {'ticker': 'GGM'}
# {'ticker': 'GGP_A'}
# {'ticker': 'GGT_B'}
# {'ticker': 'GGZ_A'}
# {'ticker': 'GHC'}
# {'ticker': 'GHS'}
# {'ticker': 'GHY'}
# {'ticker': 'GHYG'}
# {'ticker': 'GIGB'}
# {'ticker': 'GJH'}
# {'ticker': 'GJO'}
# {'ticker': 'GJP'}
# {'ticker': 'GJR'}
# {'ticker': 'GJS'}
# {'ticker': 'GJT'}
# {'ticker': 'GJV'}
# {'ticker': 'GLA'}
# {'ticker': 'GLDW'}
# {'ticker': 'GLOG_A'}
# {'ticker': 'GLOP_A'}
# {'ticker': 'GM-WS-B'}
# {'ticker': 'GMFL'}
# {'ticker': 'GMTA'}
# {'ticker': 'GMZ'}
# {'ticker': 'GNE_A'}
# {'ticker': 'GNL'}
# {'ticker': 'GNRT'}
# {'ticker': 'GNT'}
# {'ticker': 'GOAU'}
# {'ticker': 'GOEX'}
# {'ticker': 'GOF'}
# {'ticker': 'GOLF'}
# {'ticker': 'GOOS'}
# {'ticker': 'GPE_A'}
# {'ticker': 'GPMT'}
# {'ticker': 'GPT'}
# {'ticker': 'GPT_A'}
# {'ticker': 'GRNB'}
# {'ticker': 'GRP-U'}
# {'ticker': 'GRR'}
# {'ticker': 'GRX'}
# {'ticker': 'GRX_A'}
# {'ticker': 'GRX_B'}
# {'ticker': 'GS_A'}
# {'ticker': 'GS_B'}
# {'ticker': 'GS_C'}
# {'ticker': 'GS_D'}
# {'ticker': 'GS_I'}
# {'ticker': 'GS_J'}
# {'ticker': 'GS_K'}
# {'ticker': 'GS_N'}
# {'ticker': 'GSBD'}
# {'ticker': 'GSD'}
# {'ticker': 'GSEU'}
# {'ticker': 'GSHTW'}
# {'ticker': 'GSIE'}
# {'ticker': 'GSJY'}
# {'ticker': 'GSL_B'}
# {'ticker': 'GSLC'}
# {'ticker': 'GSSC'}
# {'ticker': 'GTN-A'}
# {'ticker': 'GTO'}
# {'ticker': 'GUT_A'}
# {'ticker': 'GUT_C'}
# {'ticker': 'GVIP'}
# {'ticker': 'GXP_B'}
# {'ticker': 'GYB'}
# {'ticker': 'GYC'}
# {'ticker': 'HACK'}
# {'ticker': 'HACV'}
# {'ticker': 'HACW'}
# {'ticker': 'HAKK'}
# {'ticker': 'HAUD'}
# {'ticker': 'HAWX'}
# {'ticker': 'HBM-WS'}
# {'ticker': 'HCC'}
# {'ticker': 'HCN_I'}
# {'ticker': 'HCOR'}
# {'ticker': 'HCRF'}
# {'ticker': 'HDAW'}
# {'ticker': 'HDEE'}
# {'ticker': 'HDEF'}
# {'ticker': 'HDEZ'}
# {'ticker': 'HDLV'}
# {'ticker': 'HDMV'}
# {'ticker': 'HDRW'}
# {'ticker': 'HDWX'}
# {'ticker': 'HE_U'}
# {'ticker': 'HEFV'}
# {'ticker': 'HEI-A'}
# {'ticker': 'HEMV'}
# {'ticker': 'HEQ'}
# {'ticker': 'HES_A'}
# {'ticker': 'HESM'}
# {'ticker': 'HEUS'}
# {'ticker': 'HEUV'}
# {'ticker': 'HEWC'}
# {'ticker': 'HEWI'}
# {'ticker': 'HEWL'}
# {'ticker': 'HEWP'}
# {'ticker': 'HEWU'}
# {'ticker': 'HEWW'}
# {'ticker': 'HEWY'}
# {'ticker': 'HFEZ'}
# {'ticker': 'HFXE'}
# {'ticker': 'HFXI'}
# {'ticker': 'HFXJ'}
# {'ticker': 'HGEU'}
# {'ticker': 'HGJP'}
# {'ticker': 'HGSD'}
# {'ticker': 'HGV'}
# {'ticker': 'HHYX'}
# {'ticker': 'HIE'}
# {'ticker': 'HIFR'}
# {'ticker': 'HIG-WS'}
# {'ticker': 'HIPS'}
# {'ticker': 'HJPX'}
# {'ticker': 'HJV'}
# {'ticker': 'HK-WS'}
# {'ticker': 'HL_B'}
# {'ticker': 'HOME'}
# {'ticker': 'HOML'}
# {'ticker': 'HPE'}
# {'ticker': 'HQBD'}
# {'ticker': 'HSBC_A'}
# {'ticker': 'HSCZ'}
# {'ticker': 'HSEA'}
# {'ticker': 'HSEB'}
# {'ticker': 'HT_C'}
# {'ticker': 'HT_D'}
# {'ticker': 'HT_E'}
# {'ticker': 'HTUS'}
# {'ticker': 'HUNTW'}
# {'ticker': 'HUSV'}
# {'ticker': 'HVT-A'}
# {'ticker': 'HYDD'}
# {'ticker': 'HYHG'}
# {'ticker': 'HYI'}
# {'ticker': 'HYLB'}
# {'ticker': 'HYLV'}
# {'ticker': 'HYXU'}
# {'ticker': 'HZN'}
# {'ticker': 'IAE'}
# {'ticker': 'IAGG'}
# {'ticker': 'IBDR'}
# {'ticker': 'IBMJ'}
# {'ticker': 'IBMK'}
# {'ticker': 'IBML'}
# {'ticker': 'IBO'}
# {'ticker': 'ICAN'}
# {'ticker': 'ICL'}
# {'ticker': 'ICOW'}
# {'ticker': 'ICSH'}
# {'ticker': 'ICVT'}
# {'ticker': 'IDE'}
# {'ticker': 'IDEV'}
# {'ticker': 'IDHD'}
# {'ticker': 'IDMO'}
# {'ticker': 'IFIX'}
# {'ticker': 'IFLY'}
# {'ticker': 'IFN'}
# {'ticker': 'IGEM'}
# {'ticker': 'IGHG'}
# {'ticker': 'IGI'}
# {'ticker': 'IGRO'}
# {'ticker': 'IGVT'}
# {'ticker': 'IHD'}
# {'ticker': 'IHIT'}
# {'ticker': 'IID'}
# {'ticker': 'IMOM'}
# {'ticker': 'IMTB'}
# {'ticker': 'INB'}
# {'ticker': 'INDF'}
# {'ticker': 'INF'}
# {'ticker': 'INFR'}
# {'ticker': 'ING'}
# {'ticker': 'INN_B'}
# {'ticker': 'INN_C'}
# {'ticker': 'INN_D'}
# {'ticker': 'INST'}
# {'ticker': 'INVH'}
# {'ticker': 'IPAY'}
# {'ticker': 'IPL_D'}
# {'ticker': 'IPOS'}
# {'ticker': 'IQDG'}
# {'ticker': 'IRET_B'}
# {'ticker': 'IRR'}
# {'ticker': 'ISF'}
# {'ticker': 'ISG'}
# {'ticker': 'ISMD'}
# {'ticker': 'ISP'}
# {'ticker': 'ISZE'}
# {'ticker': 'ITCB'}
# {'ticker': 'ITGR'}
# {'ticker': 'ITML'}
# {'ticker': 'ITMS'}
# {'ticker': 'IVAL'}
# {'ticker': 'IVH'}
# {'ticker': 'IVLU'}
# {'ticker': 'IVR_A'}
# {'ticker': 'IVR_B'}
# {'ticker': 'IYLD'}
# {'ticker': 'JAG'}
# {'ticker': 'JBK'}
# {'ticker': 'JBN'}
# {'ticker': 'JBR'}
# {'ticker': 'JCI'}
# {'ticker': 'JCO'}
# {'ticker': 'JE_A'}
# {'ticker': 'JELD'}
# {'ticker': 'JETS'}
# {'ticker': 'JFC'}
# {'ticker': 'JGH'}
# {'ticker': 'JHA'}
# {'ticker': 'JHB'}
# {'ticker': 'JHD'}
# {'ticker': 'JHG'}
# {'ticker': 'JHMA'}
# {'ticker': 'JHMC'}
# {'ticker': 'JHMD'}
# {'ticker': 'JHME'}
# {'ticker': 'JHMF'}
# {'ticker': 'JHMH'}
# {'ticker': 'JHMI'}
# {'ticker': 'JHML'}
# {'ticker': 'JHMM'}
# {'ticker': 'JHMS'}
# {'ticker': 'JHMT'}
# {'ticker': 'JHMU'}
# {'ticker': 'JHY'}
# {'ticker': 'JILL'}
# {'ticker': 'JLS'}
# {'ticker': 'JMF'}
# {'ticker': 'JMLP'}
# {'ticker': 'JMM'}
# {'ticker': 'JMPB'}
# {'ticker': 'JMPC'}
# {'ticker': 'JMT'}
# {'ticker': 'JP'}
# {'ticker': 'JPEH'}
# {'ticker': 'JPEM'}
# {'ticker': 'JPEU'}
# {'ticker': 'JPGB'}
# {'ticker': 'JPHF'}
# {'ticker': 'JPHY'}
# {'ticker': 'JPIH'}
# {'ticker': 'JPIN'}
# {'ticker': 'JPM-WS'}
# {'ticker': 'JPM_A'}
# {'ticker': 'JPM_B'}
# {'ticker': 'JPM_D'}
# {'ticker': 'JPM_E'}
# {'ticker': 'JPM_F'}
# {'ticker': 'JPM_G'}
# {'ticker': 'JPM_H'}
# {'ticker': 'JPME'}
# {'ticker': 'JPN'}
# {'ticker': 'JPSE'}
# {'ticker': 'JPST'}
# {'ticker': 'JPT'}
# {'ticker': 'JPUS'}
# {'ticker': 'JPW'}
# {'ticker': 'JPXN'}
# {'ticker': 'JRI'}
# {'ticker': 'JSD'}
# {'ticker': 'JUNE'}
# {'ticker': 'JW-A'}
# {'ticker': 'JW-B'}
# {'ticker': 'KCNY'}
# {'ticker': 'KDMN'}
# {'ticker': 'KEMP'}
# {'ticker': 'KEN'}
# {'ticker': 'KEY_I'}
# {'ticker': 'KFN_'}
# {'ticker': 'KIM_I'}
# {'ticker': 'KIM_J'}
# {'ticker': 'KIM_K'}
# {'ticker': 'KIO'}
# {'ticker': 'KKR_A'}
# {'ticker': 'KKR_B'}
# {'ticker': 'KLDW'}
# {'ticker': 'KMF'}
# {'ticker': 'KMI_A'}
# {'ticker': 'KODK-WS-A'}
# {'ticker': 'KODK-WS'}
# {'ticker': 'KOR'}
# {'ticker': 'KRC_H'}
# {'ticker': 'KREF'}
# {'ticker': 'KRP'}
# {'ticker': 'KSA'}
# {'ticker': 'KSU_'}
# {'ticker': 'KTH'}
# {'ticker': 'KTN'}
# {'ticker': 'KTP'}
# {'ticker': 'KYN_F'}
# {'ticker': 'LABS'}
# {'ticker': 'LARE'}
# {'ticker': 'LBDC'}
# {'ticker': 'LDP'}
# {'ticker': 'LEAD'}
# {'ticker': 'LEN-B'}
# {'ticker': 'LGF-A'}
# {'ticker': 'LGF-B'}
# {'ticker': 'LHO_I'}
# {'ticker': 'LHO_J'}
# {'ticker': 'LKSD'}
# {'ticker': 'LMHA'}
# {'ticker': 'LNC-WS'}
# {'ticker': 'LPG'}
# {'ticker': 'LRET'}
# {'ticker': 'LSI'}
# {'ticker': 'LSVX'}
# {'ticker': 'LTM'}
# {'ticker': 'LVHB'}
# {'ticker': 'LVHE'}
# {'ticker': 'LVHI'}
# {'ticker': 'LVIN'}
# {'ticker': 'LVUS'}
# {'ticker': 'LXP_C'}
# {'ticker': 'MAA_I'}
# {'ticker': 'MATF'}
# {'ticker': 'MDLQ'}
# {'ticker': 'MDLX'}
# {'ticker': 'MDLY'}
# {'ticker': 'MEAR'}
# {'ticker': 'MELT'}
# {'ticker': 'MENU'}
# {'ticker': 'MER_K'}
# {'ticker': 'MER_P'}
# {'ticker': 'MET_A'}
# {'ticker': 'MEXX'}
# {'ticker': 'MFA_B'}
# {'ticker': 'MFCB'}
# {'ticker': 'MGP'}
# {'ticker': 'MH_A'}
# {'ticker': 'MH_C'}
# {'ticker': 'MH_D'}
# {'ticker': 'MHLA'}
# {'ticker': 'MHNB-CL'}
# {'ticker': 'MHO_A'}
# {'ticker': 'MIE'}
# {'ticker': 'MITT_A'}
# {'ticker': 'MITT_B'}
# {'ticker': 'MKC-V'}
# {'ticker': 'MLPB'}
# {'ticker': 'MLPE'}
# {'ticker': 'MLPQ'}
# {'ticker': 'MLPZ'}
# {'ticker': 'MLTI'}
# {'ticker': 'MNR_B-CL'}
# {'ticker': 'MNR_B'}
# {'ticker': 'MNR_C'}
# {'ticker': 'MOG-A'}
# {'ticker': 'MOG-B'}
# {'ticker': 'MORE'}
# {'ticker': 'MOTI'}
# {'ticker': 'MP_D'}
# {'ticker': 'MRRL'}
# {'ticker': 'MRT'}
# {'ticker': 'MS_A'}
# {'ticker': 'MS_E'}
# {'ticker': 'MS_F'}
# {'ticker': 'MS_G'}
# {'ticker': 'MS_I'}
# {'ticker': 'MS_K'}
# {'ticker': 'MSGN'}
# {'ticker': 'MTB-WS'}
# {'ticker': 'MTB_'}
# {'ticker': 'MTB_C'}
# {'ticker': 'MTL_'}
# {'ticker': 'MTT'}
# {'ticker': 'MULE'}
# {'ticker': 'MVIN'}
# {'ticker': 'MXF'}
# {'ticker': 'NAIL'}
# {'ticker': 'NANR'}
# {'ticker': 'NAV_D'}
# {'ticker': 'NBB'}
# {'ticker': 'NBD'}
# {'ticker': 'NBLX'}
# {'ticker': 'NDP'}
# {'ticker': 'NEE_C'}
# {'ticker': 'NEE_G'}
# {'ticker': 'NEE_H'}
# {'ticker': 'NEE_I'}
# {'ticker': 'NEE_J'}
# {'ticker': 'NEE_K'}
# {'ticker': 'NEE_Q'}
# {'ticker': 'NEE_R'}
# {'ticker': 'NETS'}
# {'ticker': 'NEV'}
# {'ticker': 'NFLT'}
# {'ticker': 'NGL_B'}
# {'ticker': 'NGLS_A'}
# {'ticker': 'NGVT'}
# {'ticker': 'NHA'}
# {'ticker': 'NID'}
# {'ticker': 'NIE'}
# {'ticker': 'NIQ'}
# {'ticker': 'NLY_A'}
# {'ticker': 'NLY_C'}
# {'ticker': 'NLY_D'}
# {'ticker': 'NLY_E'}
# {'ticker': 'NM_G'}
# {'ticker': 'NM_H'}
# {'ticker': 'NMK_B'}
# {'ticker': 'NMK_C'}
# {'ticker': 'NMS'}
# {'ticker': 'NNN_E'}
# {'ticker': 'NNN_F'}
# {'ticker': 'NOMD'}
# {'ticker': 'NRE'}
# {'ticker': 'NS_A'}
# {'ticker': 'NS_B'}
# {'ticker': 'NSA'}
# {'ticker': 'NSS'}
# {'ticker': 'NTB'}
# {'ticker': 'NTG'}
# {'ticker': 'NUAG'}
# {'ticker': 'NUDM'}
# {'ticker': 'NUEM'}
# {'ticker': 'NULG'}
# {'ticker': 'NULV'}
# {'ticker': 'NUMG'}
# {'ticker': 'NUMV'}
# {'ticker': 'NURE'}
# {'ticker': 'NUSA'}
# {'ticker': 'NUSC'}
# {'ticker': 'NUW'}
# {'ticker': 'NW_C'}
# {'ticker': 'NXRT'}
# {'ticker': 'NYCB_A'}
# {'ticker': 'NYCB_U'}
# {'ticker': 'NYLD-A'}
# {'ticker': 'OAKS_A'}
# {'ticker': 'OAPH'}
# {'ticker': 'OASI'}
# {'ticker': 'OBE'}
# {'ticker': 'OCIO'}
# {'ticker': 'OEUH'}
# {'ticker': 'OEUR'}
# {'ticker': 'OEW'}
# {'ticker': 'OFC_L-CL'}
# {'ticker': 'OFG_A'}
# {'ticker': 'OFG_B'}
# {'ticker': 'OFG_D'}
# {'ticker': 'OGCP'}
# {'ticker': 'OIBR-C'}
# {'ticker': 'OIIL'}
# {'ticker': 'OILB'}
# {'ticker': 'OILD'}
# {'ticker': 'OILK'}
# {'ticker': 'OILU'}
# {'ticker': 'OILX'}
# {'ticker': 'OMAA'}
# {'ticker': 'OMAM'}
# {'ticker': 'OMF'}
# {'ticker': 'ONEO'}
# {'ticker': 'ONEV'}
# {'ticker': 'ONEY'}
# {'ticker': 'ONTL'}
# {'ticker': 'OPP'}
# {'ticker': 'OR'}
# {'ticker': 'ORC'}
# {'ticker': 'OSB'}
# {'ticker': 'OSG'}
# {'ticker': 'OUSA'}
# {'ticker': 'OUSM'}
# {'ticker': 'OVLC'}
# {'ticker': 'PAVE'}
# {'ticker': 'PBI_B'}
# {'ticker': 'PBR-A'}
# {'ticker': 'PBR'}
# {'ticker': 'PCK'}
# {'ticker': 'PEB_C'}
# {'ticker': 'PEB_D'}
# {'ticker': 'PEI_A'}
# {'ticker': 'PEI_B'}
# {'ticker': 'PEI_C'}
# {'ticker': 'PEN'}
# {'ticker': 'PFFR'}
# {'ticker': 'PFGC'}
# {'ticker': 'PFH'}
# {'ticker': 'PFV'}
# {'ticker': 'PGRE'}
# {'ticker': 'PGZ'}
# {'ticker': 'PHYS'}
# {'ticker': 'PIY'}
# {'ticker': 'PJT'}
# {'ticker': 'PK'}
# {'ticker': 'PL_C'}
# {'ticker': 'PL_E'}
# {'ticker': 'PLYM'}
# {'ticker': 'PMT_A'}
# {'ticker': 'PNC-WS'}
# {'ticker': 'PNC_P'}
# {'ticker': 'PNC_Q'}
# {'ticker': 'PNTA-CL'}
# {'ticker': 'PPLN'}
# {'ticker': 'PPX'}
# {'ticker': 'PRE_F'}
# {'ticker': 'PRE_G'}
# {'ticker': 'PRE_H'}
# {'ticker': 'PRE_I'}
# {'ticker': 'PRME'}
# {'ticker': 'PRNT'}
# {'ticker': 'PSA_A'}
# {'ticker': 'PSA_B'}
# {'ticker': 'PSA_C'}
# {'ticker': 'PSA_D'}
# {'ticker': 'PSA_E'}
# {'ticker': 'PSA_F'}
# {'ticker': 'PSA_S'}
# {'ticker': 'PSA_T'}
# {'ticker': 'PSA_U'}
# {'ticker': 'PSA_V'}
# {'ticker': 'PSA_W'}
# {'ticker': 'PSA_X'}
# {'ticker': 'PSA_Y'}
# {'ticker': 'PSA_Z'}
# {'ticker': 'PSB_T'}
# {'ticker': 'PSB_U'}
# {'ticker': 'PSB_V'}
# {'ticker': 'PSB_W'}
# {'ticker': 'PSF'}
# {'ticker': 'PSLV'}
# {'ticker': 'PSMB'}
# {'ticker': 'PSMC'}
# {'ticker': 'PSMG'}
# {'ticker': 'PSMM'}
# {'ticker': 'PSTG'}
# {'ticker': 'PTEU'}
# {'ticker': 'PTLC'}
# {'ticker': 'PTMC'}
# {'ticker': 'PTNQ'}
# {'ticker': 'PUK_'}
# {'ticker': 'PUK_A'}
# {'ticker': 'PUMP'}
# {'ticker': 'PUTW'}
# {'ticker': 'PYS'}
# {'ticker': 'PYT'}
# {'ticker': 'QCP'}
# {'ticker': 'QGTA'}
# {'ticker': 'QHC'}
# {'ticker': 'QMOM'}
# {'ticker': 'QVAL'}
# {'ticker': 'QVM'}
# {'ticker': 'QXGG'}
# {'ticker': 'QXMI'}
# {'ticker': 'QXRR'}
# {'ticker': 'QXTR'}
# {'ticker': 'RA'}
# {'ticker': 'RACE'}
# {'ticker': 'RAS_A'}
# {'ticker': 'RAS_B'}
# {'ticker': 'RAS_C'}
# {'ticker': 'RBS'}
# {'ticker': 'RBS_F'}
# {'ticker': 'RBS_H'}
# {'ticker': 'RBS_L'}
# {'ticker': 'RBS_S'}
# {'ticker': 'RCOM'}
# {'ticker': 'RDS-A'}
# {'ticker': 'RDS-B'}
# {'ticker': 'REG_G'}
# {'ticker': 'RELX'}
# {'ticker': 'REML'}
# {'ticker': 'RENX'}
# {'ticker': 'REVG'}
# {'ticker': 'REXR_A'}
# {'ticker': 'RF_A'}
# {'ticker': 'RF_B'}
# {'ticker': 'RFCI'}
# {'ticker': 'RFDA'}
# {'ticker': 'RFFC'}
# {'ticker': 'RFUN'}
# {'ticker': 'RGT'}
# {'ticker': 'RISE'}
# {'ticker': 'RIV'}
# {'ticker': 'RNR_C'}
# {'ticker': 'RNR_E'}
# {'ticker': 'ROAM'}
# {'ticker': 'RODM'}
# {'ticker': 'ROGS'}
# {'ticker': 'RORE'}
# {'ticker': 'ROUS'}
# {'ticker': 'RPAI_A'}
# {'ticker': 'RPT_D'}
# {'ticker': 'RSO_A'}
# {'ticker': 'RSO_B'}
# {'ticker': 'RSO_C'}
# {'ticker': 'RXIIW'}
# {'ticker': 'RXN_A'}
# {'ticker': 'RY_S'}
# {'ticker': 'RY_T'}
# {'ticker': 'RYAM_A'}
# {'ticker': 'SAFE'}
# {'ticker': 'SAN_A'}
# {'ticker': 'SAN_B'}
# {'ticker': 'SAN_C'}
# {'ticker': 'SAN_I'}
# {'ticker': 'SB_B'}
# {'ticker': 'SB_C'}
# {'ticker': 'SB_D'}
# {'ticker': 'SBBC'}
# {'ticker': 'SBGLR'}
# {'ticker': 'SBOW'}
# {'ticker': 'SCAP'}
# {'ticker': 'SCCI'}
# {'ticker': 'SCE_F-CL'}
# {'ticker': 'SCE_F'}
# {'ticker': 'SCE_G'}
# {'ticker': 'SCE_H'}
# {'ticker': 'SCE_J'}
# {'ticker': 'SCE_K'}
# {'ticker': 'SCE_L'}
# {'ticker': 'SCHW_B'}
# {'ticker': 'SCHW_C'}
# {'ticker': 'SCHW_D'}
# {'ticker': 'SF_A'}
# {'ticker': 'SFHY'}
# {'ticker': 'SFIG'}
# {'ticker': 'SFR'}
# {'ticker': 'SGQI'}
# {'ticker': 'SHAG'}
# {'ticker': 'SHE'}
# {'ticker': 'SHNY'}
# {'ticker': 'SHO_E'}
# {'ticker': 'SHO_F'}
# {'ticker': 'SICK'}
# {'ticker': 'SLG_I'}
# {'ticker': 'SMD'}
# {'ticker': 'SMHD'}
# {'ticker': 'SMHI'}
# {'ticker': 'SMIN'}
# {'ticker': 'SMM'}
# {'ticker': 'SMMV'}
# {'ticker': 'SNAP'}
# {'ticker': 'SNDR'}
# {'ticker': 'SNR'}
# {'ticker': 'SNV_C'}
# {'ticker': 'SOI'}
# {'ticker': 'SOP'}
# {'ticker': 'SOV_C'}
# {'ticker': 'SOVB'}
# {'ticker': 'SPDN'}
# {'ticker': 'SPE_B'}
# {'ticker': 'SPG_J'}
# {'ticker': 'SPGI'}
# {'ticker': 'SPLP_A'}
# {'ticker': 'SPMO'}
# {'ticker': 'SPPP'}
# {'ticker': 'SPUN'}
# {'ticker': 'SPVM'}
# {'ticker': 'SPVU'}
# {'ticker': 'SPXC'}
# {'ticker': 'SPXE'}
# {'ticker': 'SPXN'}
# {'ticker': 'SPXT'}
# {'ticker': 'SPXV'}
# {'ticker': 'SPYD'}
# {'ticker': 'SPYX'}
# {'ticker': 'SQ'}
# {'ticker': 'SR'}
# {'ticker': 'SRF'}
# {'ticker': 'SRG'}
# {'ticker': 'SSW_D'}
# {'ticker': 'SSW_E'}
# {'ticker': 'SSW_G'}
# {'ticker': 'SSW_H'}
# {'ticker': 'STAG_B'}
# {'ticker': 'STAG_C'}
# {'ticker': 'STAR_D'}
# {'ticker': 'STAR_E'}
# {'ticker': 'STAR_F'}
# {'ticker': 'STAR_G'}
# {'ticker': 'STAR_I'}
# {'ticker': 'STI-WS-A'}
# {'ticker': 'STI-WS-B'}
# {'ticker': 'STI_A'}
# {'ticker': 'STI_E'}
# {'ticker': 'STK'}
# {'ticker': 'STOR'}
# {'ticker': 'STOT'}
# {'ticker': 'STT_C'}
# {'ticker': 'STT_D'}
# {'ticker': 'STT_E'}
# {'ticker': 'STT_G'}
# {'ticker': 'STZ-B'}
# {'ticker': 'SUI_A'}
# {'ticker': 'SUPV'}
# {'ticker': 'SWP'}
# {'ticker': 'SZC'}
# {'ticker': 'TAIL'}
# {'ticker': 'TAP-A'}
# {'ticker': 'TBLU'}
# {'ticker': 'TCF-WS'}
# {'ticker': 'TCF'}
# {'ticker': 'TCF_B'}
# {'ticker': 'TCF_C'}
# {'ticker': 'TCHF'}
# {'ticker': 'TCO_J'}
# {'ticker': 'TCO_K'}
# {'ticker': 'TCTL'}
# {'ticker': 'TECZ'}
# {'ticker': 'TERM'}
# {'ticker': 'TETF'}
# {'ticker': 'TGP_A'}
# {'ticker': 'THQ'}
# {'ticker': 'THW'}
# {'ticker': 'TI-A'}
# {'ticker': 'TLDH'}
# {'ticker': 'TLEH'}
# {'ticker': 'TLRD'}
# {'ticker': 'TMK_B'}
# {'ticker': 'TMK_C'}
# {'ticker': 'TNP_B'}
# {'ticker': 'TNP_C'}
# {'ticker': 'TNP_D'}
# {'ticker': 'TNP_E'}
# {'ticker': 'TOO_A'}
# {'ticker': 'TOO_B'}
# {'ticker': 'TPGE-U'}
# {'ticker': 'TPGE-WS'}
# {'ticker': 'TPGE'}
# {'ticker': 'TPGH-U'}
# {'ticker': 'TPOR'}
# {'ticker': 'TPVG'}
# {'ticker': 'TPVZ'}
# {'ticker': 'TPYP'}
# {'ticker': 'TPZ'}
# {'ticker': 'TRNO_A-CL'}
# {'ticker': 'TRNO_A'}
# {'ticker': 'TRTN'}
# {'ticker': 'TSLF'}
# {'ticker': 'TTAC'}
# {'ticker': 'TTAI'}
# {'ticker': 'TTP'}
# {'ticker': 'TVC'}
# {'ticker': 'TVE'}
# {'ticker': 'TWLO'}
# {'ticker': 'TWN'}
# {'ticker': 'TWO_A'}
# {'ticker': 'TY_'}
# {'ticker': 'UBA'}
# {'ticker': 'UBP'}
# {'ticker': 'UBP_F'}
# {'ticker': 'UBP_G'}
# {'ticker': 'UCIB'}
# {'ticker': 'UE'}
# {'ticker': 'UMH_A'}
# {'ticker': 'UMH_B'}
# {'ticker': 'UOP'}
# {'ticker': 'USB_A'}
# {'ticker': 'USB_H'}
# {'ticker': 'USB_M'}
# {'ticker': 'USB_O'}
# {'ticker': 'USMF'}
# {'ticker': 'USMR'}
# {'ticker': 'USRT'}
# {'ticker': 'UTES'}
# {'ticker': 'UTLF'}
# {'ticker': 'UTLZ'}
# {'ticker': 'UTSL'}
# {'ticker': 'UWT'}
# {'ticker': 'VALE-P'}
# {'ticker': 'VAMO'}
# {'ticker': 'VER'}
# {'ticker': 'VER_F'}
# {'ticker': 'VIST'}
# {'ticker': 'VLY-WS'}
# {'ticker': 'VLY_A'}
# {'ticker': 'VMAX'}
# {'ticker': 'VMIN'}
# {'ticker': 'VMOT'}
# {'ticker': 'VNLA'}
# {'ticker': 'VNO_G'}
# {'ticker': 'VNO_I'}
# {'ticker': 'VNO_K'}
# {'ticker': 'VNO_L'}
# {'ticker': 'VR_A'}
# {'ticker': 'VR_B'}
# {'ticker': 'VRTSP'}
# {'ticker': 'VSDA'}
# {'ticker': 'VSM'}
# {'ticker': 'VST'}
# {'ticker': 'VTEB'}
# {'ticker': 'VTRB'}
# {'ticker': 'VVV'}
# {'ticker': 'WAAS'}
# {'ticker': 'WBIA'}
# {'ticker': 'WBIB'}
# {'ticker': 'WBIC'}
# {'ticker': 'WBID'}
# {'ticker': 'WBIE'}
# {'ticker': 'WBIF'}
# {'ticker': 'WBIG'}
# {'ticker': 'WBIH'}
# {'ticker': 'WBII'}
# {'ticker': 'WBIL'}
# {'ticker': 'WBIR'}
# {'ticker': 'WBIY'}
# {'ticker': 'WBS_E'}
# {'ticker': 'WBT'}
# {'ticker': 'WDRW'}
# {'ticker': 'WEAR'}
# {'ticker': 'WEXP'}
# {'ticker': 'WFC-WS'}
# {'ticker': 'WFC_J'}
# {'ticker': 'WFC_L'}
# {'ticker': 'WFC_N'}
# {'ticker': 'WFC_O'}
# {'ticker': 'WFC_P'}
# {'ticker': 'WFC_Q'}
# {'ticker': 'WFC_R'}
# {'ticker': 'WFC_T'}
# {'ticker': 'WFC_V'}
# {'ticker': 'WFC_W'}
# {'ticker': 'WFC_X'}
# {'ticker': 'WFC_Y'}
# {'ticker': 'WFE_A'}
# {'ticker': 'WFHY'}
# {'ticker': 'WFIG'}
# {'ticker': 'WIL'}
# {'ticker': 'WLH'}
# {'ticker': 'WOW'}
# {'ticker': 'WPG_H'}
# {'ticker': 'WPG_I'}
# {'ticker': 'WPM'}
# {'ticker': 'WRB_B'}
# {'ticker': 'WRB_C'}
# {'ticker': 'WRB_D'}
# {'ticker': 'WSKY'}
# {'ticker': 'WSO-B'}
# {'ticker': 'WTID'}
# {'ticker': 'WTIU'}
# {'ticker': 'WTRX'}
# {'ticker': 'WTTR'}
# {'ticker': 'WUSA'}
# {'ticker': 'WYDE'}
# {'ticker': 'XCEM'}
# {'ticker': 'XD'}
# {'ticker': 'XE'}
# {'ticker': 'XF'}
# {'ticker': 'XH'}
# {'ticker': 'XI'}
# {'ticker': 'XINA'}
# {'ticker': 'XITK'}
# {'ticker': 'XIVH'}
# {'ticker': 'XK'}
# {'ticker': 'XKE'}
# {'ticker': 'XLRE'}
# {'ticker': 'XM'}
# {'ticker': 'XMX'}
# {'ticker': 'XRF'}
# {'ticker': 'XS'}
# {'ticker': 'XSHD'}
# {'ticker': 'XSHQ'}
# {'ticker': 'XTH'}
# {'ticker': 'XU'}
# {'ticker': 'XUSA'}
# {'ticker': 'XWEB'}
# {'ticker': 'YEXT'}
# {'ticker': 'YLD'}
# {'ticker': 'YRD'}
# {'ticker': 'ZB_A'}
# {'ticker': 'ZB_F-CL'}
# {'ticker': 'ZB_G'}
# {'ticker': 'ZB_H'}
# {'ticker': 'ZBZX'}
# {'ticker': 'ZVV'}
# {'ticker': 'ZYME'}
# {'ticker': 'ABE'}
# {'ticker': 'ADK_A'}
# {'ticker': 'AIII'}
# {'ticker': 'AINC'}
# {'ticker': 'ARNC_'}
# {'ticker': 'ASB-WS'}
# {'ticker': 'AST-WS'}
# {'ticker': 'AUXO'}
# {'ticker': 'BCV_A'}
# {'ticker': 'BRG'}
# {'ticker': 'BRG_A'}
# {'ticker': 'BRG_C'}
# {'ticker': 'BRG_D'}
# {'ticker': 'BTX-WS'}
# {'ticker': 'BWL-A'}
# {'ticker': 'CEI'}
# {'ticker': 'CRHM'}
# {'ticker': 'CVM-WS'}
# {'ticker': 'ERN'}
# {'ticker': 'ESNC'}
# {'ticker': 'FPP-WS'}
# {'ticker': 'GDP'}
# {'ticker': 'GGN_B'}
# {'ticker': 'GGO'}
# {'ticker': 'GGO_A'}
# {'ticker': 'GLU_A'}
# {'ticker': 'GST_A'}
# {'ticker': 'GST_B'}
# {'ticker': 'HCAC-U'}
# {'ticker': 'HLM_'}
# {'ticker': 'HLTH'}
# {'ticker': 'IMUC-WS'}
# {'ticker': 'IPB'}
# {'ticker': 'JRJR'}
# {'ticker': 'LTS_A'}
# {'ticker': 'MICR'}
# {'ticker': 'MPO'}
# {'ticker': 'MTNB'}
# {'ticker': 'NML'}
# {'ticker': 'NSAT'}
# {'ticker': 'NSPR-WS-B'}
# {'ticker': 'NSPR-WS'}
# {'ticker': 'NXE'}
# {'ticker': 'OCX'}
# {'ticker': 'PARR'}
# {'ticker': 'PCG_A'}
# {'ticker': 'PCG_B'}
# {'ticker': 'PCG_C'}
# {'ticker': 'PCG_D'}
# {'ticker': 'PCG_E'}
# {'ticker': 'PCG_G'}
# {'ticker': 'PCG_H'}
# {'ticker': 'PCG_I'}
# {'ticker': 'PW_A'}
# {'ticker': 'RLGT_A'}
# {'ticker': 'SACH'}
# {'ticker': 'SCE_B'}
# {'ticker': 'SCE_C'}
# {'ticker': 'SCE_D'}
# {'ticker': 'SCE_E'}
# {'ticker': 'SENS'}
# {'ticker': 'SRCI'}
# {'ticker': 'SVM'}
# {'ticker': 'TEUM'}
# {'ticker': 'TKAT'}
# {'ticker': 'TPHS'}
# {'ticker': 'USAS'}
# {'ticker': 'UUUU-WS'}
# {'ticker': 'UUUU'}
# {'ticker': 'WRN'}
# {'ticker': 'XTNT'}
# {'ticker': 'ZDGE'}

# %%
sector
# Out:
# {'Basic Materials': 519,
#  'Conglomerates': 32,
#  'Consumer Goods': 348,
#  'Financial': 1437,
#  'Healthcare': 645,
#  'Industrial Goods': 330,
#  'Services': 759,
#  'Technology': 726,
#  'Utilities': 116}

# %%
for each in tickerInfo:
    if 'category' in each:
        if each['category'] not in category:
            category[each['category']] = 1
        else:
            category[each['category']] += 1

# %%
category
# Out:
# {'Aerospace/Defense': 43,
#  'Automotive': 60,
#  'Banking': 439,
#  'Chemicals': 88,
#  'Computer Hardware': 48,
#  'Computer Software & Services': 256,
#  'Conglomerates': 32,
#  'Consumer Durables': 69,
#  'Consumer NonDurables': 114,
#  'Diversified Services': 208,
#  'Drugs': 419,
#  'Electronics': 200,
#  'Energy': 297,
#  'Financial Services': 596,
#  'Food & Beverage': 97,
#  'Health Services': 226,
#  'Insurance': 137,
#  'Internet': 66,
#  'Leisure': 117,
#  'Manufacturing': 173,
#  'Materials & Construction': 114,
#  'Media': 101,
#  'Metals & Mining': 134,
#  'Real Estate': 265,
#  'Retail': 98,
#  'Specialty Retail': 67,
#  'Telecommunications': 156,
#  'Tobacco': 8,
#  'Transportation': 123,
#  'Utilities': 116,
#  'Wholesale': 45}
